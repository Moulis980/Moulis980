# %% [markdown]
# <a href="https://colab.research.google.com/github/Moulis980/Moulis980/blob/main/Sample_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("/content/HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  ...  promotion_last_5years  Department  salary
# 0                0.38             0.53               2  ...                      0       sales     low
# 1                0.80             0.86               5  ...                      0       sales  medium
# 2                0.11             0.88               7  ...                      0       sales  medium
# 3                0.72             0.87               5  ...                      0       sales     low
# 4                0.37             0.52               2  ...                      0       sales     low
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (14999, 10)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df[["satisfaction_level","number_project"]],df.salary,test_size=0.2)

# %%
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#        satisfaction_level  number_project
# 10226                0.62               4
# 1811                 0.45               2
# 12061                0.11               7
# 10341                0.69               4
# 13800                0.78               3
# ...                   ...             ...
# 5075                 0.98               5
# 4776                 0.63               3
# 2800                 0.94               5
# 9179                 0.84               4
# 134                  0.36               2
#
# [3000 rows x 2 columns]

# %%
Y_test
# Out:
# 10226    medium
# 1811        low
# 12061    medium
# 10341       low
# 13800    medium
#           ...
# 5075        low
# 4776     medium
# 2800     medium
# 9179        low
# 134         low
# Name: salary, Length: 3000, dtype: object

# %%
model.predict(X_test)
# Out:
# array(['low', 'low', 'low', ..., 'medium', 'low', 'low'], dtype=object)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.08250005, 0.48303841, 0.43446154],
#        [0.08022256, 0.50621635, 0.41356109],
#        [0.06148285, 0.52640719, 0.41210996],
#        ...,
#        [0.09225483, 0.44728129, 0.46046387],
#        [0.09057405, 0.46030302, 0.44912293],
#        [0.07710052, 0.51552639, 0.40737309]])

# %%
model.score(X_test,Y_test)
# Out:
# 0.49633333333333335
